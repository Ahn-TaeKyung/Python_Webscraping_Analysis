# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# %pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: c:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract
# Note: you may need to restart the kernel to use updated packages.

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# %pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: c:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert
# Note: you may need to restart the kernel to use updated packages.

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 {requests.__version__}')
print(f'beautifulsoup4 버전 {bs4.__version__}')
# Out:
# requests 버전 2.32.3
# beautifulsoup4 버전 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# url2 = 'https://news.naver.com/section/105'
# 요청 헤더 설정 : 브라우저 정보 (사람처럼 보이게 하려고 설정하는 것)
req_header = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers = req_header)
print(res)
print(type(res))
print(res.status_code, res.ok)
# 응답(response)이 OK 이면
if res.ok:
    pass
    # 응답 (response)에서 text 추출  - source 보기기
    html = res.text
    # print(html)
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html, 'html.parser') 
    # print(soup)

    # CSS 선택자
    # <div class = 'sa_text'><a href=''></a></div>
    print(len(soup.select("div.sa_text a[href*='mnews/article']")))
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    a_tag_list = soup.select("div.sa_text a[href*='mnews/article']")
    print(type(a_tag_list))

    # <a> 태그 리스트 순회하기    
    for a_tag in a_tag_list:
        # print(type(a_tag))
        title = a_tag.text.strip()
        link = a_tag['href']
        print(link, '\n',title)
    
else:
    # 응답(response)이 Error 이면 status code 출력    
    print(f'에러 코드 = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# <Response [200]>
# <class 'requests.models.Response'>
# 200 True
# 86
# <class 'bs4.element.ResultSet'>
# https://n.news.naver.com/mnews/article/243/0000075979
#  금융·통신 손잡고 보이스피싱 차단…기업은행·SKT, 탐지 서비스 오픈
# https://n.news.naver.com/mnews/article/comment/243/0000075979
#
# https://n.news.naver.com/mnews/article/029/0002946563
#  중앙아시아·유럽으로 넓어지는 韓 우주협력 영토
# https://n.news.naver.com/mnews/article/comment/029/0002946563
#
# https://n.news.naver.com/mnews/article/003/0013169598
#  카카오메이커스, 출범 9년 만에 누적 거래액 1조원 돌파
# https://n.news.naver.com/mnews/article/comment/003/0013169598
#
# https://n.news.naver.com/mnews/article/011/0004471555
#  뤼튼 "5000만 국민 모두에게 생활형 AI 제공할 것"
# https://n.news.naver.com/mnews/article/comment/011/0004471555
#
# https://n.news.naver.com/mnews/article/014/0005332827
#  정부, 스미싱 문자 사전 차단하는 '엑스레이' 서비스 시범 운영
# https://n.news.naver.com/mnews/article/comment/014/0005332827
#
# https://n.news.naver.com/mnews/article/031/0000922675
#  신세계아이앤씨, 'AI 계산대' 출시…"리테일테크 시장 공략 가속"
# https://n.news.naver.com/mnews/article/comment/031/0000922675
#
# https://n.news.naver.com/mnews/article/029/0002946651
#  슈퍼박테리아 치료 길 열어…특정 병원균만 사멸
# https://n.news.naver.com/mnews/article/comment/029/0002946651
#
# https://n.news.naver.com/mnews/article/092/0002369827
#  리플 "전 세계 금융 시장, 실물자산 토큰화 중심으로 근본 변화"
# https://n.news.naver.com/mnews/article/comment/092/0002369827
#
# https://n.news.naver.com/mnews/article/421/0008180569
#  에이비엘바이오, '4조 기술이전' 후 첫 공식석상…로드맵 밝힌다
# https://n.news.naver.com/mnews/article/comment/421/0008180569
#
# https://n.news.naver.com/mnews/article/421/0008180565
#  "의료계 제안 논의하자"…의협, 정부·국회에 '대화의 장' 요구
# https://n.news.naver.com/mnews/article/comment/421/0008180565
#
# https://n.news.naver.com/mnews/article/081/0003531724
#  항암제 피하는 암세포 꼼수 발견…악성 폐암도 잡는다
# https://n.news.naver.com/mnews/article/comment/081/0003531724
#
# https://n.news.naver.com/mnews/article/421/0008180537
#  뤼튼 "무료전략으로 생활형 AI 시대 열 것…올해 천만 MAU 목표"
# https://n.news.naver.com/mnews/article/comment/421/0008180537
#
# https://n.news.naver.com/mnews/article/032/0003361993
#  첫 한국계 ‘NASA 우주비행사’ 조니 김, 마침내 지구 궤도로 떠났다
# https://n.news.naver.com/mnews/article/comment/032/0003361993
#
# https://n.news.naver.com/mnews/article/015/0005116525
#  질병청, 세계 첫 단백질 재조합 탄저백신 '배리트락스' 상용화
# https://n.news.naver.com/mnews/article/comment/015/0005116525
#
# https://n.news.naver.com/mnews/article/092/0002369818
#  트럼프 관세, 세계경제 큰 타격…美中 충돌로 더 증폭
# https://n.news.naver.com/mnews/article/comment/092/0002369818
#
# https://n.news.naver.com/mnews/article/366/0001067643
#  [100세 과학] 노년 건강 유지엔 채식보다 육식
# https://n.news.naver.com/mnews/article/comment/366/0001067643
#
# https://n.news.naver.com/mnews/article/018/0005982461
#  [사고]스테이블코인 vs CBDC…디지털금융 대세는 어디로?
# https://n.news.naver.com/mnews/article/comment/018/0005982461
#
# https://n.news.naver.com/mnews/article/021/0002701758
#  폐암 면역치료 새 전략 찾았다…면역항암 막는 핵심인자 최초로 발견
# https://n.news.naver.com/mnews/article/comment/021/0002701758
#
# https://n.news.naver.com/mnews/article/092/0002369817
#  "갤럭시S26 울트라, 카메라 사양 등 전작과 큰 변화 없다"
# https://n.news.naver.com/mnews/article/comment/092/0002369817
#
# https://n.news.naver.com/mnews/article/092/0002369816
#  구영배 "위시 살려야" 주장에 피해자들 분통…"차라리 처벌 받아라"
# https://n.news.naver.com/mnews/article/comment/092/0002369816
#
# https://n.news.naver.com/mnews/article/092/0002369815
#  관세 폭탄에 스마트폰 공장 美로 옮긴다?…"가능성 희박"
# https://n.news.naver.com/mnews/article/comment/092/0002369815
#
# https://n.news.naver.com/mnews/article/015/0005116508
#  전국에 딱 500대만 풀린다…'한정판 갤럭시S25'의 정체
# https://n.news.naver.com/mnews/article/comment/015/0005116508
#
# https://n.news.naver.com/mnews/article/030/0003301337
#  [6G 코리아] ④ 이통3사, AI-RAN 시장 개척 주도
# https://n.news.naver.com/mnews/article/comment/030/0003301337
#
# https://n.news.naver.com/mnews/article/015/0005116502
#  한바이오 "모유두세포로 탈모 정복하겠다"
# https://n.news.naver.com/mnews/article/comment/015/0005116502
#
# https://n.news.naver.com/mnews/article/293/0000065879
#  뤼튼, 감정 교류도 하는 'AI 비서' 낸다
# https://n.news.naver.com/mnews/article/comment/293/0000065879
#
# https://n.news.naver.com/mnews/article/092/0002369813
#  온라인서 예금토큰 결제 지연…9일부터 순차적으로 진행
# https://n.news.naver.com/mnews/article/comment/092/0002369813
#
# https://n.news.naver.com/mnews/article/030/0003301326
#  법인 가상자산 투자 허용, 금융 생태계 지각변동 예고...우덕수 블록데몬 아시아 대표 “기관 대상 상품 본격화”
# https://n.news.naver.com/mnews/article/comment/030/0003301326
#
# https://n.news.naver.com/mnews/article/366/0001067631
#  美와 AI 격차 좁힌 中…한국은 AI 투자 줄어
# https://n.news.naver.com/mnews/article/comment/366/0001067631
#
# https://n.news.naver.com/mnews/article/030/0003301320
#  LS전선, 대한전선 상대 특허 최종 승소…양측 상고 포기
# https://n.news.naver.com/mnews/article/comment/030/0003301320
#
# https://n.news.naver.com/mnews/article/023/0003898272
#  사람 태워 산속 누빈다... 늑대 닮은 日 4족보행 로봇 공개
# https://n.news.naver.com/mnews/article/comment/023/0003898272
#
# https://n.news.naver.com/mnews/article/030/0003301315
#  삼성전자 시장예상 뛰어넘은 1분기 실적...매출 79조·영업익 6.6조
# https://n.news.naver.com/mnews/article/comment/030/0003301315
#
# https://n.news.naver.com/mnews/article/421/0008180285
#  '2인 체제' 방통위 논란 여전…이대로면 '줄소송' 가능성
# https://n.news.naver.com/mnews/article/comment/421/0008180285
#
# https://n.news.naver.com/mnews/article/015/0005116490
#  "영락없는 자녀 목소린데"…AI 보이스피싱, AI로 방지
# https://n.news.naver.com/mnews/article/comment/015/0005116490
#
# https://n.news.naver.com/mnews/article/138/0002194264
#  DDR5 가격 불 붙인 中 CXMT…삼성⋅SK '반사이익' 장기화 기대 [소부장반차장]
# https://n.news.naver.com/mnews/article/comment/138/0002194264
#
# https://n.news.naver.com/mnews/article/029/0002946687
#  100년간 해킹 불가… 팬시코인, 세계 최초 `양자암호내성 블록체인 지갑` 승인
# https://n.news.naver.com/mnews/article/comment/029/0002946687
#
# https://n.news.naver.com/mnews/article/030/0003301302
#  중소 알뜰폰 '저가형'에 대기업 알뜰폰, '이색 요금제'
# https://n.news.naver.com/mnews/article/comment/030/0003301302
#
# https://n.news.naver.com/mnews/article/421/0008180265
#  질병청, 국내 기술로 최초 단백질 탄저백신 개발…'26년 결실'(종합)
# https://n.news.naver.com/mnews/article/comment/421/0008180265
#
# https://n.news.naver.com/mnews/article/030/0003301301
#  [IT구루 간담회] AI 에이전트 등 응용분야 육성 전략, 인재양성 패러다임 전환해야
# https://n.news.naver.com/mnews/article/comment/030/0003301301
#
# https://n.news.naver.com/mnews/article/277/0005574594
#  "가구 배치, 옷 코디도 도와준다"…제미나이 라이브 갤S25 적용
# https://n.news.naver.com/mnews/article/comment/277/0005574594
#
# https://n.news.naver.com/mnews/article/030/0003301290
#  매그나칩, DDI 사업 청산…임직원 해고 통보
# https://n.news.naver.com/mnews/article/comment/030/0003301290
#
# https://n.news.naver.com/mnews/article/009/0005472676
#  상금 30억원 내건 슈퍼센트, ‘제4회 슈퍼센트 게임 챌린지’ 개최
# https://n.news.naver.com/mnews/article/comment/009/0005472676
#
# https://n.news.naver.com/mnews/article/584/0000031781
#  항생제 내성 슈퍼박테리아, 나노입자 결합시켜 열로 제거한다
# https://n.news.naver.com/mnews/article/comment/584/0000031781
#
# https://n.news.naver.com/mnews/article/366/0001067619
#  MS가 주목한 韓 스타트업 뤼튼 “전 국민 맞춤형 AI 시대 만든다”
# https://n.news.naver.com/mnews/article/comment/366/0001067619

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup


section_dict = {
    100: "정치",
    101: "경제",
    102: "사회",
    103: "생활/문화",
    104: "세계",
    105: "IT/과학",
}


def print_news(sid):  # print_new(103,'생활/문화')
    section = section_dict[sid]

    url = f"https://news.naver.com/section/{sid}"
    print(url, section, "뉴스")

    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36"
    }

    # requests 의 get() 함수 호출하기
    res = requests.get(url, headers=req_header)
    print(res)
    print(type(res))
    print(res.status_code, res.ok)

    if res.ok:
        pass
        # 응답 (response)에서 text 추출  - source 보기기
        html = res.text
        # print(html)
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
        # print(soup)

        # CSS 선택자
        # <div class = 'sa_text'><a href=''></a></div>
        print(len(soup.select("div.sa_text a[href*='mnews/article']")))
        # print(soup.select("div.sa_text a[href*='mnews/article']"))
        a_tag_list = soup.select("div.sa_text a[href*='mnews/article']")
        print(type(a_tag_list))

        # <a> 태그 리스트 순회하기
        for a_tag in a_tag_list:
            # print(type(a_tag))
            title = a_tag.text.strip()
            link = a_tag["href"]
            print(link, "\n", title)

    else:
        # 응답(response)이 Error 이면 status code 출력
        print(f"에러 코드 = {res.status_code}")


print_news(100)
# Out:
# https://news.naver.com/section/100 정치 뉴스
# <Response [200]>
# <class 'requests.models.Response'>
# 200 True
# 92
# <class 'bs4.element.ResultSet'>
# https://n.news.naver.com/mnews/article/656/0000127872
#  우원식 "韓, 헌법재판관 지명 사과하고 철회하라…국회 무시한 것"
# https://n.news.naver.com/mnews/article/comment/656/0000127872
#
# https://n.news.naver.com/mnews/article/022/0004025777
#  ‘그때는 맞고 지금은 틀린’ 개헌 논의…李 3년 전 공약, 지금은 “적기 아냐”
# https://n.news.naver.com/mnews/article/comment/022/0004025777
#
# https://n.news.naver.com/mnews/article/214/0001416800
#  일 외교청서 "독도는 일본 땅‥징용 배상은 한국이 지급"
# https://n.news.naver.com/mnews/article/comment/214/0001416800
#
# https://n.news.naver.com/mnews/article/016/0002454055
#  김민석 “용산에 계속 대통령실? 대부분 국민 동의 안할 것”
# https://n.news.naver.com/mnews/article/comment/016/0002454055
#
# https://n.news.naver.com/mnews/article/055/0001247443
#  "국민에 예의 아냐" 손사래 치더니…"국민이 원한다" 김문수 출마 위해 사의 표명[자막뉴스]
# https://n.news.naver.com/mnews/article/comment/055/0001247443
#
# https://n.news.naver.com/mnews/article/015/0005116446
#  대선후보등록 5월 10∼11일…사전투표는 5월 29·30일
# https://n.news.naver.com/mnews/article/comment/015/0005116446
#
# https://n.news.naver.com/mnews/article/079/0004011426
#  안철수, 네 번째 대권 도전…"이재명 이길 유일한 적임자"
# https://n.news.naver.com/mnews/article/comment/079/0004011426
#
# https://n.news.naver.com/mnews/article/469/0000858179
#  선관위 '특혜 채용' 논란 고위직 자녀 10명 이달 중 청문 실시
# https://n.news.naver.com/mnews/article/comment/469/0000858179
#
# https://n.news.naver.com/mnews/article/011/0004471501
#  대통령 선거일 6월 3일로 확정…임시공휴일 지정
# https://n.news.naver.com/mnews/article/comment/011/0004471501
#
# https://n.news.naver.com/mnews/article/008/0005177451
#  한동훈, 10일 국회에서 대선 출마 선언…"국민 통합·미래 강조"
# https://n.news.naver.com/mnews/article/comment/008/0005177451
#
# https://n.news.naver.com/mnews/article/008/0005177574
#  김문수·한동훈·안철수·김동연 등 대권 잠룡들, 잇따라 출마 공식화
# https://n.news.naver.com/mnews/article/comment/008/0005177574
#
# https://n.news.naver.com/mnews/article/014/0005332980
#  與  '한덕수 차출론' 솔솔, 왜?
# https://n.news.naver.com/mnews/article/comment/014/0005332980
#
# https://n.news.naver.com/mnews/article/469/0000858335
#  "애순에게도 '서울런'이 있었다면"...서울시 회의에서 '폭싹 속았수다' 언급된 이유는?
# https://n.news.naver.com/mnews/article/comment/469/0000858335
#
# https://n.news.naver.com/mnews/article/032/0003362021
#  홍준표 “사형” “헌재 폐지” “페미니즘이 국가 해체”···‘막말’과 ‘홍카콜라’ 줄타기
# https://n.news.naver.com/mnews/article/comment/032/0003362021
#
# https://n.news.naver.com/mnews/article/047/0002469017
#  "이장우, 내란옹호 사과 없이 대선 출마 언급은 시민 우롱"
# https://n.news.naver.com/mnews/article/comment/047/0002469017
#
# https://n.news.naver.com/mnews/article/079/0004011491
#  파면당한 윤석열, 차기 대통령 선거 나올 수 있다?[노컷체크]
# https://n.news.naver.com/mnews/article/comment/079/0004011491
#
# https://n.news.naver.com/mnews/article/052/0002177214
#  이재명 "대통령인 줄 착각" vs 국민의힘 "높이 평가"
# https://n.news.naver.com/mnews/article/comment/052/0002177214
#
# https://n.news.naver.com/mnews/article/661/0000053247
#  尹 전 대통령, 11일 한남동 관저 비운다.. ‘서초→제3지’ 수순 밟나
# https://n.news.naver.com/mnews/article/comment/661/0000053247
#
# https://n.news.naver.com/mnews/article/025/0003432698
#  관저 나가는 尹부부 이삿짐 포착…오는 11일 퇴거할 듯
# https://n.news.naver.com/mnews/article/comment/025/0003432698
#
# https://n.news.naver.com/mnews/article/586/0000100928
#  국민이 그들을 '양아치'라고 부르는 진짜 이유[박용후의 관점]
# https://n.news.naver.com/mnews/article/comment/586/0000100928
#
# https://n.news.naver.com/mnews/article/025/0003432697
#  전한길 "'尹어게인' 지지…개헌 통해 헌재 가루 되도록 할 것"
# https://n.news.naver.com/mnews/article/comment/025/0003432697
#
# https://n.news.naver.com/mnews/article/016/0002454420
#  공군 전투기 몰래 촬영한 中학생은 공안 자녀
# https://n.news.naver.com/mnews/article/comment/016/0002454420
#
# https://n.news.naver.com/mnews/article/025/0003432695
#  의장·양당 회동에 불참한 박찬대…국민의힘 "이재명만 안면몰수"
# https://n.news.naver.com/mnews/article/comment/025/0003432695
#
# https://n.news.naver.com/mnews/article/001/0015317903
#  21대 대통령 선거일 '6월 3일 화요일' 확정…임시공휴일 지정(종합2보)
# https://n.news.naver.com/mnews/article/comment/001/0015317903
#
# https://n.news.naver.com/mnews/article/008/0005177555
#  이준석 "10억 내기" 걸었던 학력 의혹…경찰, 하버드대서 '졸업' 확인
# https://n.news.naver.com/mnews/article/comment/008/0005177555
#
# https://n.news.naver.com/mnews/article/005/0001768514
#  “대선의 디귿(ㄷ) 자도 꺼내지 말라” 한덕수, 출마설 일축
# https://n.news.naver.com/mnews/article/comment/005/0001768514
#
# https://n.news.naver.com/mnews/article/055/0001247443
#  [자막뉴스] "국민에 예의 아냐" 손사래 치더니…"국민이 원한다" 김문수 출마 위해 사의 표명
# https://n.news.naver.com/mnews/article/comment/055/0001247443
#
# https://n.news.naver.com/mnews/article/421/0008180733
#  '광화문광장·인천공항·맥아더동상'…출마 장소에 의지 담는다
# https://n.news.naver.com/mnews/article/comment/421/0008180733
#
# https://n.news.naver.com/mnews/article/081/0003531744
#  홍준표 “나는 본선 보고 뛴다…대선은 洪-李 양자구도”
# https://n.news.naver.com/mnews/article/comment/081/0003531744
#
# https://n.news.naver.com/mnews/article/008/0005177551
#  한덕수 '尹측근' 헌법재판관 지명에 野 격앙 "내란세력 헌재 장악 시도"
# https://n.news.naver.com/mnews/article/comment/008/0005177551
#
# https://n.news.naver.com/mnews/article/003/0013171214
#  헌법재판관 후보자로 지명된 '윤 최측근' 이완규 법제처장 [뉴시스Pic]
# https://n.news.naver.com/mnews/article/comment/003/0013171214
#
# https://n.news.naver.com/mnews/article/016/0002454416
#  “이번엔 빠져 달라” 국회 연금개혁특위, 첫날부터 충돌
# https://n.news.naver.com/mnews/article/comment/016/0002454416
#
# https://n.news.naver.com/mnews/article/081/0003531741
#  “王자에 놀란 가슴”…안철수 손가락에도 의문의 글자 포착
# https://n.news.naver.com/mnews/article/comment/081/0003531741
#
# https://n.news.naver.com/mnews/article/421/0008180706
#  '이효진 원광大'…이번엔 안철수 손가락에 6글자, 무슨 의미?
# https://n.news.naver.com/mnews/article/comment/421/0008180706
#
# https://n.news.naver.com/mnews/article/123/0002356554
#  한덕수, '尹 40년지기‧호위무사' 헌법재판관 지명...국회 격앙 "청문회 안한다"
# https://n.news.naver.com/mnews/article/comment/123/0002356554
#
# https://n.news.naver.com/mnews/article/657/0000037003
#  홍준표 "탄핵되면 차기 대선 포기해야···당이 없어지는 거지" 2024년 9월 'TV홍카콜라' 다시 봤더니
# https://n.news.naver.com/mnews/article/comment/657/0000037003
#
# https://n.news.naver.com/mnews/article/437/0000436364
#  "대통령 복귀 바랐다" 김문수가 말한 '윤과의 관계' [현장영상]
# https://n.news.naver.com/mnews/article/comment/437/0000436364
#
# https://n.news.naver.com/mnews/article/014/0005332961
#  조갑제 "국힘, 지난 4개월 간 악령에 접수…'국민배반당' 된 것"
# https://n.news.naver.com/mnews/article/comment/014/0005332961
#
# https://n.news.naver.com/mnews/article/020/0003626812
#  이완규 “엄중한 시기에 큰 책임감…후속 절차 잘 준비할 것”
# https://n.news.naver.com/mnews/article/comment/020/0003626812
#
# https://n.news.naver.com/mnews/article/022/0004025990
#  윤석열 동기 최측근 ‘안가회동’ 이완규 헌재 재판관 지명에… 조국혁신당 “모든 법적 조치”
# https://n.news.naver.com/mnews/article/comment/022/0004025990
#
# https://n.news.naver.com/mnews/article/448/0000519257
#  홍준표 "김문수형은 탈레반, 나는 유연…대통령 되면 청와대 복귀"
# https://n.news.naver.com/mnews/article/comment/448/0000519257
#
# https://n.news.naver.com/mnews/article/008/0005177538
#  "이재명=히틀러, 김문수=탈레반…난 유연해" 견제구 던진 홍준표
# https://n.news.naver.com/mnews/article/comment/008/0005177538
#
# https://n.news.naver.com/mnews/article/088/0000940756
#  황교안 대선 출마 예고 "국민의힘 탈당한다"
# https://n.news.naver.com/mnews/article/comment/088/0000940756
#
# https://n.news.naver.com/mnews/article/079/0004011460
#  여전히 '국힘 1호 당원' 尹…이준석 "당 말아먹은 수괴인데"[오목조목]
# https://n.news.naver.com/mnews/article/comment/079/0004011460
#
# https://n.news.naver.com/mnews/article/055/0001247422
#  한 대행 "대선의 'ㄷ'도 꺼내지마라"…여의도발 잇단 출마설 일축
# https://n.news.naver.com/mnews/article/comment/055/0001247422
#
# https://n.news.naver.com/mnews/article/448/0000519256
#  韓대행 "글자 'ㄷ'도 꺼내지마라"…여의도발 출마설 일축
# https://n.news.naver.com/mnews/article/comment/448/0000519256

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer': 'https://comic.naver.com/webtoon/detail?titleId=798173&no=5&amp;weekday=thu'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers = req_header)
    if res.ok:
        # binary 응답 데이터 가져오기 content 프로퍼티 사용용
        img_data = res.content
        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        # print(file_name)
        # binday data를 file에 write하기
        with open(file_name, 'wb') as file:
            print(f'Writing to {file_name}({len(img_data)} bytes)')
            file.write(img_data)
# Out:
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg(299319 bytes)
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg(163333 bytes)
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg(182530 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
